# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
from konlpy.tag import Okt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./review_train.csv')
print(df.shape)
df.head()
# Out:
# (50000, 2)
#                                               review  score
# 0  오늘 오니기리와 이규동 가서 돈가스랑 계란규동 먹었는데 진짜 합리적인 가격에 호강했...    5.0
# 1  여기는 미스터파파 임실치즈피자 인가 그렇습니다 저도 낚였네요 피자는 가격 저렴한 만...    2.0
# 2   숯불닭갈비가 그런맛이였다니 처음 먹어본 닭갈비 진짜맛있었어요 춘천또가보고싶네요 정말강추    5.0
# 3  바하커피샵 전체적인 분위기는 작고 부담이 없다고 할까 하지만 커피맛이 좋은집 카페인...    3.0
# 4                                페북에서 봤는데 가관   장사 망     1.0

# %%
def score_evaluate(score):
    if score >= 3.5:
        return 1
    else:
        return 0
df['NP'] = df['score'].apply(score_evaluate) # 긍부정 여부 1,0으로 라벨링

# %%
df.head()
# Out:
#                                               review  score  NP
# 0  오늘 오니기리와 이규동 가서 돈가스랑 계란규동 먹었는데 진짜 합리적인 가격에 호강했...    5.0   1
# 1  여기는 미스터파파 임실치즈피자 인가 그렇습니다 저도 낚였네요 피자는 가격 저렴한 만...    2.0   0
# 2   숯불닭갈비가 그런맛이였다니 처음 먹어본 닭갈비 진짜맛있었어요 춘천또가보고싶네요 정말강추    5.0   1
# 3  바하커피샵 전체적인 분위기는 작고 부담이 없다고 할까 하지만 커피맛이 좋은집 카페인...    3.0   0
# 4                                페북에서 봤는데 가관   장사 망     1.0   0

# %%
len(df[df['NP']==1])/len(df) # 긍정인 반응 / 전체 반응
# Out:
# 0.55596

# %%
import re

# %%
def text_clearing(text): 
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+')
    # 지정한 정규식에 해당하지 않은 것은 길이가 0인 문자열로 변환
    result = hangul.sub('', text)
    return result

# %%
df["ko_review"] = df["review"].apply(lambda x : text_clearing(x))

# %%
df.drop("review", axis=1, inplace=True)
df
# Out:
#        score  NP                                          ko_review
# 0        5.0   1  오늘 오니기리와 이규동 가서 돈가스랑 계란규동 먹었는데 진짜 합리적인 가격에 호강했...
# 1        2.0   0  여기는 미스터파파 임실치즈피자 인가 그렇습니다 저도 낚였네요 피자는 가격 저렴한 만...
# 2        5.0   1   숯불닭갈비가 그런맛이였다니 처음 먹어본 닭갈비 진짜맛있었어요 춘천또가보고싶네요 정말강추
# 3        3.0   0  바하커피샵 전체적인 분위기는 작고 부담이 없다고 할까 하지만 커피맛이 좋은집 카페인...
# 4        1.0   0                                페북에서 봤는데 가관   장사 망
# ...      ...  ..                                                ...
# 49995    5.0   1                      하얀짜장 맛있어요 짬뽕도 얼큰하고 든든하게 먹고갑니다
# 49996    5.0   1  친절하시고 반찬도 많아 좋았어요 직접 산에서 해오신 나물들이라고 설명듣고 먹어보니 ...
# 49997    1.0   0  옛날에 좋은 추억이 있어 오랫만에 방문했는데 많이 변했더라구요 카페분위기도 어수선하...
# 49998    4.5   1  저는 되게 맛있게 먹고왔어서요 부산에 가본 횟집들 부산이라는 이름만 있지 막상 가보...
# 49999    1.0   0  진짜 부산여행하면서 처음으로 부산온게 후회가 되었어요 정말 이때꺼지 먹어본 냉면중에...
#
# [50000 rows x 3 columns]

# %% [markdown]
# 형태소분석

# %%
from konlpy.tag import Okt

# %%
stopwords = ['도','한','는','은','이','가','와','로','에','들','의','과','자','의','좀','잘','걍','으로','하다','님','다','를','을','자','랑','게','그','에서']

# %%
okt = Okt()

# %%
okt_review = []
for sentence in df['ko_review']:
    tokenized_sentence = okt.morphs(sentence, stem=True)
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    okt_review.append(stopwords_removed_sentence)

# %%
okt_review[0][:10]
# Out:
# ['오늘', '오니기리', '이규동', '가다', '돈가스', '계란', '규동', '먹다', '진짜', '합리']

# %% [markdown]
# 토큰화 & 패딩

# %%
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# 정수 인코딩 (텍스트를 숫자로 처리할 수 있도록 훈련, 테스트 데이터에 정수 인코딩) 
tokenizer = Tokenizer() 
tokenizer.fit_on_texts(okt_review)

# 단어 집합 생성 -> 높은 숫자일수록 등장 빈도수가 낮음. 
# 등장 빈도수 낮은애들 제거 
word_min = 2 
total_count = len(tokenizer.word_index) 
rare_count = 0 # 등장이 2회 미만

# 빈도수 VALUE 
for key,value in tokenizer.word_counts.items(): 
    if value < word_min: 
        rare_count = rare_count + 1

# %%
vocab_size = total_count - rare_count + 2 # OOV와 padding 때문에 +2

# %%
vocab_size
# Out:
# 16919

# %%
tokenizer = Tokenizer(vocab_size, oov_token='OOV') # OOV 토큰 
tokenizer.fit_on_texts(okt_review)

# %%
word_dic = tokenizer.word_index
word_dic
# Out:
# {'OOV': 1,
#  '먹다': 2,
#  '맛있다': 3,
#  '맛': 4,
#  '좋다': 5,
#  '가다': 6,
#  '없다': 7,
#  '보다': 8,
#  '있다': 9,
#  '시키다': 10,
#  '너무': 11,
#  '정말': 12,
#  '이다': 13,
#  '안': 14,
#  '친절하다': 15,
#  '요': 16,
#  '같다': 17,
#  '오다': 18,
#  '사장': 19,
#  '진짜': 20,
#  '고': 21,
#  '여기': 22,
#  '않다': 23,
#  '되다': 24,
#  '만': 25,
#  '곳': 26,
#  '나오다': 27,
#  '음식': 28,
#  '집': 29,
#  '아니다': 30,
#  '분': 31,
#  '받다': 32,
#  '서비스': 33,
#  '하고': 34,
#  '배달': 35,
#  '들다': 36,
#  '가격': 37,
#  '때': 38,
#  '많다': 39,
#  '완전': 40,
#  '그렇다': 41,
#  '사람': 42,
#  '서': 43,
#  '다른': 44,
#  '나': 45,
#  '주문': 46,
#  '손님': 47,
#  '치킨': 48,
#  '주다': 49,
#  '직원': 50,
#  '말': 51,
#  '더': 52,
#  '못': 53,
#  '기분': 54,
#  '전화': 55,
#  '그냥': 56,
#  '고기': 57,
#  '또': 58,
#  '저': 59,
#  '네': 60,
#  '나다': 61,
#  '것': 62,
#  '아깝다': 63,
#  '많이': 64,
#  '두': 65,
#  '추천': 66,
#  '괜찮다': 67,
#  '인데': 68,
#  '까지': 69,
#  '알다': 70,
#  '시간': 71,
#  '자다': 72,
#  '해주다': 73,
#  '말다': 74,
#  '제': 75,
#  '돈': 76,
#  '깔끔하다': 77,
#  '생각': 78,
#  '안되다': 79,
#  '별': 80,
#  '최고': 81,
#  '모르다': 82,
#  '갈다': 83,
#  '장사': 84,
#  '이랑': 85,
#  '넘다': 86,
#  '한번': 87,
#  '처음': 88,
#  '가보다': 89,
#  '맛집': 90,
#  '불친절하다': 91,
#  '자주': 92,
#  '인': 93,
#  '중': 94,
#  '적': 95,
#  '전': 96,
#  '하나': 97,
#  '싶다': 98,
#  '개': 99,
#  '밥': 100,
#  '별로': 101,
#  '정도': 102,
#  '가게': 103,
#  '다시': 104,
#  '다시다': 105,
#  '원': 106,
#  '면': 107,
#  '잇다': 108,
#  '내': 109,
#  '일': 110,
#  '분위기': 111,
#  '왜': 112,
#  '점': 113,
#  '아': 114,
#  '짱': 115,
#  '하': 116,
#  '반찬': 117,
#  '차다': 118,
#  '이라': 119,
#  '보고': 120,
#  '그리고': 121,
#  '식당': 122,
#  '주인': 123,
#  '양': 124,
#  '뭐': 125,
#  '지': 126,
#  '거': 127,
#  '짬뽕': 128,
#  '시': 129,
#  '양도': 130,
#  '좋아하다': 131,
#  '이네': 132,
#  '최악': 133,
#  '기다리다': 134,
#  '번': 135,
#  '이렇다': 136,
#  '엄청': 137,
#  '들어가다': 138,
#  '기': 139,
#  '쓰다': 140,
#  '친구': 141,
#  '맛없다': 142,
#  '짜다': 143,
#  '다음': 144,
#  '늘다': 145,
#  '분들': 146,
#  '피자': 147,
#  '이나': 148,
#  '부터': 149,
#  '메뉴': 150,
#  '만들다': 151,
#  '꼭': 152,
#  '글': 153,
#  '가족': 154,
#  '특히': 155,
#  '여': 156,
#  '여기다': 157,
#  '알바': 158,
#  '국물': 159,
#  '인지': 160,
#  '닭': 161,
#  '엔': 162,
#  '앞': 163,
#  '듯': 164,
#  '평가': 165,
#  '임': 166,
#  '오늘': 167,
#  '지다': 168,
#  '수': 169,
#  '라': 170,
#  '찾다': 171,
#  '이렇게': 172,
#  '마다': 173,
#  '비싸다': 174,
#  '강추': 175,
#  '버리다': 176,
#  '가지': 177,
#  '알바생': 178,
#  '대박': 179,
#  '전화하다': 180,
#  '건지다': 181,
#  '족발': 182,
#  '주': 183,
#  '같이': 184,
#  '적다': 185,
#  '아주': 186,
#  '포장': 187,
#  '이런': 188,
#  '탕수육': 189,
#  '커피': 190,
#  '싸다': 191,
#  '양념': 192,
#  '저렴하다': 193,
#  '싸가지': 194,
#  '직접': 195,
#  '니': 196,
#  '에는': 197,
#  '튀김': 198,
#  '내다': 199,
#  '대': 200,
#  '절대': 201,
#  '불친절': 202,
#  '아줌마': 203,
#  '다르다': 204,
#  '달라': 205,
#  '에도': 206,
#  '나쁘다': 207,
#  '한테': 208,
#  '없이': 209,
#  '번창': 210,
#  '친절': 211,
#  '라고': 212,
#  '반': 213,
#  '푸다': 214,
#  '근데': 215,
#  '서다': 216,
#  '단골': 217,
#  '회': 218,
#  '살다': 219,
#  '이고': 220,
#  '맞다': 221,
#  '이라고': 222,
#  '명': 223,
#  '지금': 224,
#  '함': 225,
#  '무슨': 226,
#  '크다': 227,
#  '데': 228,
#  '넣다': 229,
#  '조금': 230,
#  '소스': 231,
#  '저희': 232,
#  '냄새': 233,
#  '깨끗하다': 234,
#  '식사': 235,
#  '제일': 236,
#  '계속': 237,
#  '방문': 238,
#  '생기다': 239,
#  '구': 240,
#  '바쁘다': 241,
#  '이에요': 242,
#  '되어다': 243,
#  '항상': 244,
#  '이집': 245,
#  '걸리다': 246,
#  '드리다': 247,
#  '식': 248,
#  '테이블': 249,
#  '니까': 250,
#  '남다': 251,
#  '문': 252,
#  '몇': 253,
#  '근처': 254,
#  '늦다': 255,
#  '살': 256,
#  '빵': 257,
#  '년': 258,
#  '날': 259,
#  '우리': 260,
#  '느낌': 261,
#  '기본': 262,
#  '바로': 263,
#  '들리다': 264,
#  '밑': 265,
#  '치즈': 266,
#  '배': 267,
#  '그렇게': 268,
#  '딱': 269,
#  '역시': 270,
#  '아주머니': 271,
#  '보이다': 272,
#  '매장': 273,
#  '걸': 274,
#  '여자': 275,
#  '장': 276,
#  '남기다': 277,
#  '계산': 278,
#  '느끼다': 279,
#  '김밥': 280,
#  '때문': 281,
#  '카드': 282,
#  '만원': 283,
#  '가면': 284,
#  '거기': 285,
#  '김치': 286,
#  '비추다': 287,
#  '찾아가다': 288,
#  '맵다': 289,
#  '굿': 290,
#  '그릇': 291,
#  '입맛': 292,
#  '인분': 293,
#  '대비': 294,
#  '자리': 295,
#  '어떻다': 296,
#  '마리': 297,
#  '일단': 298,
#  '처럼': 299,
#  '블로그': 300,
#  '짐': 301,
#  '싫다': 302,
#  '물어보다': 303,
#  '원래': 304,
#  '아이': 305,
#  '나가다': 306,
#  '교육': 307,
#  '먹기': 308,
#  '기름': 309,
#  '줄': 310,
#  '그래서': 311,
#  '올리다': 312,
#  '감사하다': 313,
#  '더럽다': 314,
#  '치다': 315,
#  '입': 316,
#  '생각나다': 317,
#  '돼다': 318,
#  '아저씨': 319,
#  '덥다': 320,
#  '써다': 321,
#  '재료': 322,
#  '인테리어': 323,
#  '비다': 324,
#  '움': 325,
#  '애': 326,
#  '밑반찬': 327,
#  '무엇': 328,
#  '떨어지다': 329,
#  '끄다': 330,
#  '실망': 331,
#  '알': 332,
#  '여행': 333,
#  '씩': 334,
#  '제대로': 335,
#  '예약': 336,
#  '음식점': 337,
#  '해': 338,
#  '순': 339,
#  '착하다': 340,
#  '난': 341,
#  '오': 342,
#  '모두': 343,
#  '남자': 344,
#  '종업원': 345,
#  '신선하다': 346,
#  '안좋다': 347,
#  '담': 348,
#  '어제': 349,
#  '이상': 350,
#  '동네': 351,
#  '따다': 352,
#  '쿠폰': 353,
#  '바뀌다': 354,
#  '다녀오다': 355,
#  '다니다': 356,
#  '튀기다': 357,
#  '옆': 358,
#  '어': 359,
#  '갈비': 360,
#  '이제': 361,
#  '그래도': 362,
#  '떡': 363,
#  '온': 364,
#  '첨': 365,
#  '해보다': 366,
#  '맘': 367,
#  '솔직하다': 368,
#  '요리': 369,
#  '짜장면': 370,
#  '달다': 371,
#  '아쉽다': 372,
#  '주방': 373,
#  '이용': 374,
#  '강': 375,
#  '비': 376,
#  '놀다': 377,
#  '죄송하다': 378,
#  '칼국수': 379,
#  '만족하다': 380,
#  '상': 381,
#  '얼마': 382,
#  '요즘': 383,
#  '밖에': 384,
#  '그런': 385,
#  '해물': 386,
#  '개인': 387,
#  '앉다': 388,
#  '돈까스': 389,
#  '진심': 390,
#  '인가': 391,
#  '저녁': 392,
#  '예요': 393,
#  '짜장': 394,
#  '에요': 395,
#  '불다': 396,
#  '쓰레기': 397,
#  '오픈': 398,
#  '끼리': 399,
#  '위생': 400,
#  '끊다': 401,
#  '바': 402,
#  '예전': 403,
#  '검색': 404,
#  '주시': 405,
#  '카페': 406,
#  '댓글': 407,
#  '종류': 408,
#  '쓸다': 409,
#  '세트': 410,
#  '후회': 411,
#  '구이': 412,
#  '주말': 413,
#  '서울': 414,
#  '짜증나다': 415,
#  '놓다': 416,
#  '이번': 417,
#  '한개': 418,
#  '고객': 419,
#  '새롭다': 420,
#  '후': 421,
#  '인상': 422,
#  '간': 423,
#  '이상하다': 424,
#  '추가': 425,
#  '멀다': 426,
#  '작다': 427,
#  '사먹다': 428,
#  '자기': 429,
#  '두다': 430,
#  '천원': 431,
#  '엉망': 432,
#  '어이': 433,
#  '야하다': 434,
#  '이건': 435,
#  '점심': 436,
#  '샐러드': 437,
#  '탕': 438,
#  '소리': 439,
#  '싱싱하다': 440,
#  '한마디': 441,
#  '믿다': 442,
#  '마음': 443,
#  '서빙': 444,
#  '안주': 445,
#  '횟집': 446,
#  '냉면': 447,
#  '질': 448,
#  '물': 449,
#  '이해': 450,
#  '빨리': 451,
#  '욕': 452,
#  '인사': 453,
#  '만두': 454,
#  '돼지': 455,
#  '손': 456,
#  '가끔': 457,
#  '유명하다': 458,
#  '굽다': 459,
#  '추하다': 460,
#  '에게': 461,
#  '거리': 462,
#  '얘기': 463,
#  '상태': 464,
#  '만족': 465,
#  '떡볶이': 466,
#  '갖다': 467,
#  '암튼': 468,
#  '이르다': 469,
#  '정신': 470,
#  '부드럽다': 471,
#  '부모님': 472,
#  '이쁘다': 473,
#  '엇': 474,
#  '시원하다': 475,
#  '용': 476,
#  '속': 477,
#  '우연히': 478,
#  '볶음밥': 479,
#  '하지만': 480,
#  '장난': 481,
#  '들르다': 482,
#  '소': 483,
#  '영업': 484,
#  '망하다': 485,
#  '죠': 486,
#  '집다': 487,
#  '짜증': 488,
#  '대다': 489,
#  '평점': 490,
#  '바꾸다': 491,
#  '본': 492,
#  '후라이드': 493,
#  '초밥': 494,
#  '오래': 495,
#  '먼저': 496,
#  '매우': 497,
#  '삼겹살': 498,
#  '함께': 499,
#  '쪽': 500,
#  '일품': 501,
#  '짱짱': 502,
#  '별하나': 503,
#  '나서다': 504,
#  '라는': 505,
#  '표정': 506,
#  '뒤': 507,
#  '기다': 508,
#  '야채': 509,
#  '얼마나': 510,
#  '빼다': 511,
#  '라면': 512,
#  '건': 513,
#  '신경': 514,
#  '제주도': 515,
#  '마인드': 516,
#  '중국집': 517,
#  '거의': 518,
#  '사': 519,
#  '가장': 520,
#  '야': 521,
#  '부산': 522,
#  '햇': 523,
#  '오랜': 524,
#  '해도': 525,
#  '술': 526,
#  '어이없다': 527,
#  '끝': 528,
#  '소문': 529,
#  '듣다': 530,
#  '타다': 531,
#  '길': 532,
#  '안나': 533,
#  '하니': 534,
#  '지만': 535,
#  '매운탕': 536,
#  '미안하다': 537,
#  '미리': 538,
#  '어디': 539,
#  '쯤': 540,
#  '들어오다': 541,
#  '매콤': 542,
#  '편하다': 543,
#  '지인': 544,
#  '말투': 545,
#  '지점': 546,
#  '대박나다': 547,
#  '느끼하다': 548,
#  '참고': 549,
#  '눈': 550,
#  '등': 551,
#  '보통': 552,
#  '지나다': 553,
#  '보내다': 554,
#  '맛보다': 555,
#  '전혀': 556,
#  '도안': 557,
#  '달': 558,
#  '겁니다': 559,
#  '참치': 560,
#  '오리': 561,
#  '동': 562,
#  '다양하다': 563,
#  '당': 564,
#  '가깝다': 565,
#  '훨씬': 566,
#  '사과': 567,
#  '비리다': 568,
#  '간장': 569,
#  '혼자': 570,
#  '땐': 571,
#  '차라리': 572,
#  '가요': 573,
#  '보쌈': 574,
#  '빠르다': 575,
#  '굳다': 576,
#  '기억': 577,
#  '여러': 578,
#  '값': 579,
#  '께서': 580,
#  '왕': 581,
#  '세': 582,
#  '엄마': 583,
#  '결제': 584,
#  '음': 585,
#  '차': 586,
#  '바라다': 587,
#  '불': 588,
#  '옷': 589,
#  '부르다': 590,
#  '감동': 591,
#  '말씀': 592,
#  '죽': 593,
#  '모임': 594,
#  '주차': 595,
#  '젊다': 596,
#  '그리다': 597,
#  '열': 598,
#  '이지만': 599,
#  '그대로': 600,
#  '뜨다': 601,
#  '따로': 602,
#  '에서는': 603,
#  '모시': 604,
#  '이유': 605,
#  '한잔': 606,
#  '넓다': 607,
#  '주변': 608,
#  '웃다': 609,
#  '몇번': 610,
#  '너': 611,
#  '먹음': 612,
#  '존나': 613,
#  '홀': 614,
#  '보': 615,
#  '생': 616,
#  '사다': 617,
#  '찍다': 618,
#  '사진': 619,
#  '영': 620,
#  '만큼': 621,
#  '갓': 622,
#  '께': 623,
#  '머': 624,
#  '수준': 625,
#  '아무': 626,
#  '감자': 627,
#  '뭔': 628,
#  '끝내주다': 629,
#  '설명': 630,
#  '국밥': 631,
#  '태도': 632,
#  '무': 633,
#  '조미료': 634,
#  '바삭': 635,
#  '가기': 636,
#  '터지다': 637,
#  '라서': 638,
#  '대로': 639,
#  '콜라': 640,
#  '그런데': 641,
#  '식다': 642,
#  '맥주': 643,
#  '힘들다': 644,
#  '파스타': 645,
#  '뿐': 646,
#  '불고기': 647,
#  '굉장하다': 648,
#  '낫다': 649,
#  '한우': 650,
#  '심': 651,
#  '위': 652,
#  '성': 653,
#  '어리다': 654,
#  '개도': 655,
#  '코스': 656,
#  '정식': 657,
#  '담백하다': 658,
#  '인심': 659,
#  '국수': 660,
#  '깔다': 661,
#  '젤': 662,
#  '놀라다': 663,
#  '인터넷': 664,
#  '버거': 665,
#  '파다': 666,
#  '반개': 667,
#  '적당하다': 668,
#  '지나가다': 669,
#  '예쁘다': 670,
#  '새우': 671,
#  '씹다': 672,
#  '편': 673,
#  '물론': 674,
#  '아무리': 675,
#  '챙기다': 676,
#  '신': 677,
#  '배부르다': 678,
#  '쉬다': 679,
#  '빠지다': 680,
#  '며': 681,
#  '막': 682,
#  '분도': 683,
#  '자체': 684,
#  '치고': 685,
#  '겁나다': 686,
#  '던지다': 687,
#  '확인': 688,
#  '기대': 689,
#  '리필': 690,
#  '모': 691,
#  '느껴지다': 692,
#  '째': 693,
#  '딱딱하다': 694,
#  '또한': 695,
#  '닭갈비': 696,
#  '잡다': 697,
#  '치우다': 698,
#  '빙수': 699,
#  '저번': 700,
#  '더니': 701,
#  '팔다': 702,
#  '이라도': 703,
#  '여서': 704,
#  '문제': 705,
#  '닫다': 706,
#  '눈치': 707,
#  '체인점': 708,
#  '똑같다': 709,
#  '나중': 710,
#  '혹시': 711,
#  '위치': 712,
#  '귀찮다': 713,
#  '관리': 714,
#  '접시': 715,
#  '스테이크': 716,
#  '이라는': 717,
#  '향': 718,
#  '방금': 719,
#  '일부러': 720,
#  '회식': 721,
#  '뼈': 722,
#  '약간': 723,
#  '불쾌하다': 724,
#  '흑': 725,
#  '층': 726,
#  '모든': 727,
#  '걸다': 728,
#  '해주시': 729,
#  '조각': 730,
#  '기도': 731,
#  '보기': 732,
#  '조': 733,
#  '낙지': 734,
#  '리': 735,
#  '이모': 736,
#  '막국수': 737,
#  '끼다': 738,
#  '간다': 739,
#  '심하다': 740,
#  '소개': 741,
#  '육수': 742,
#  '여름': 743,
#  '마지막': 744,
#  '대답': 745,
#  '신분': 746,
#  '오래되다': 747,
#  '누가': 748,
#  '이름': 749,
#  '틀다': 750,
#  '봄': 751,
#  '들이다': 752,
#  '잘못': 753,
#  '이지': 754,
#  '매번': 755,
#  '후기': 756,
#  '물다': 757,
#  '감': 758,
#  '네이버': 759,
#  '전복': 760,
#  '장어': 761,
#  '변하다': 762,
#  '매': 763,
#  '자꾸': 764,
#  '다가': 765,
#  '올': 766,
#  '얼굴': 767,
#  '장님': 768,
#  '그때': 769,
#  '그것': 770,
#  '울': 771,
#  '월': 772,
#  '화': 773,
#  '물회': 774,
#  '산': 775,
#  '음료': 776,
#  '드럽다': 777,
#  '방': 778,
#  '아직': 779,
#  '햄버거': 780,
#  '마늘': 781,
#  '갈치': 782,
#  '인거': 783,
#  '어느': 784,
#  '취소': 785,
#  '부족하다': 786,
#  '겠다': 787,
#  '래': 788,
#  '비교': 789,
#  '단체': 790,
#  '고소하다': 791,
#  '예': 792,
#  '애기': 793,
#  '죽다': 794,
#  '니깐': 795,
#  '담다': 796,
#  '평': 797,
#  '일반': 798,
#  '냐': 799,
#  '닭발': 800,
#  '즐기다': 801,
#  '데리': 802,
#  '개판': 803,
#  '줄다': 804,
#  '언제': 805,
#  '줌': 806,
#  '통': 807,
#  '스럽다': 808,
#  '왠만하다': 809,
#  '덕분': 810,
#  '아래': 811,
#  '남': 812,
#  '소고기': 813,
#  '옛날': 814,
#  '찜': 815,
#  '케익': 816,
#  '순대': 817,
#  '실망하다': 818,
#  '해달라다': 819,
#  '조개': 820,
#  '묻다': 821,
#  '기대하다': 822,
#  '늘': 823,
#  '숯불': 824,
#  '에선': 825,
#  '동안': 826,
#  '되게': 827,
#  '꽝': 828,
#  '평이': 829,
#  '진하다': 830,
#  '살이': 831,
#  '주차장': 832,
#  '참다': 833,
#  '이라서': 834,
#  '에서도': 835,
#  '지역': 836,
#  '고추': 837,
#  '개다': 838,
#  '부담': 839,
#  '든': 840,
#  '게장': 841,
#  '단': 842,
#  '제발': 843,
#  '곱창': 844,
#  '익다': 845,
#  '할인': 846,
#  '전부': 847,
#  '조용하다': 848,
#  '뭐라다': 849,
#  '굿굿': 850,
#  '둘': 851,
#  '고민': 852,
#  '천': 853,
#  '볶다': 854,
#  '볶음': 855,
#  '얼큰하다': 856,
#  '전체': 857,
#  '화장실': 858,
#  '냉동': 859,
#  '통닭': 860,
#  '건가': 861,
#  '으로도': 862,
#  '그거': 863,
#  '아침': 864,
#  '생선': 865,
#  '우동': 866,
#  '결국': 867,
#  '너무하다': 868,
#  '계시다': 869,
#  '사용': 870,
#  '차이': 871,
#  '불편하다': 872,
#  '전골': 873,
#  '회사': 874,
#  '덜': 875,
#  '똑바로': 876,
#  '외식': 877,
#  '리뷰': 878,
#  '라도': 879,
#  '삼': 880,
#  '모습': 881,
#  '이야기': 882,
#  '켯': 883,
#  '가루': 884,
#  '사모님': 885,
#  '일이': 886,
#  '한지': 887,
#  '즐겁다': 888,
#  '우선': 889,
#  '타': 890,
#  '양은': 891,
#  '돈가스': 892,
#  '추다': 893,
#  '걱정': 894,
#  '정성': 895,
#  '배고프다': 896,
#  '머리카락': 897,
#  '해드리다': 898,
#  '아들': 899,
#  '본사': 900,
#  '편이': 901,
#  '비슷하다': 902,
#  '뭔가': 903,
#  '조림': 904,
#  '안감': 905,
#  '보시': 906,
#  '개념': 907,
#  '나름': 908,
#  '시설': 909,
#  '정갈하다': 910,
#  '새': 911,
#  '백': 912,
#  '꽤': 913,
#  '중요하다': 914,
#  '이란': 915,
#  '오징어': 916,
#  '옴': 917,
#  '확실하다': 918,
#  '맨날': 919,
#  '회도': 920,
#  '카운터': 921,
#  '없어지다': 922,
#  '끼': 923,
#  '청주': 924,
#  '운영': 925,
#  '뻔하다': 926,
#  '제주': 927,
#  '여자친구': 928,
#  '다만': 929,
#  '마': 930,
#  '머리': 931,
#  '된장': 932,
#  '어른': 933,
#  '삼계탕': 934,
#  '주기도': 935,
#  '현금': 936,
#  '만족스럽다': 937,
#  '몸': 938,
#  '대해': 939,
#  '종종': 940,
#  '가져가다': 941,
#  '가능하다': 942,
#  '하루': 943,
#  '매다': 944,
#  '쭈꾸미': 945,
#  '통화': 946,
#  '경우': 947,
#  '무시': 948,
#  '더욱': 949,
#  '끝나다': 950,
#  '신랑': 951,
#  '뭘': 952,
#  '붙다': 953,
#  '가져오다': 954,
#  '준비': 955,
#  '미치다': 956,
#  '찌다': 957,
#  '인가요': 958,
#  '교촌': 959,
#  '말고': 960,
#  '그나마': 961,
#  '업체': 962,
#  '히': 963,
#  '스끼': 964,
#  '시끄럽다': 965,
#  '무한리필': 966,
#  '뷔페': 967,
#  '매일': 968,
#  '비빔밥': 969,
#  '그게': 970,
#  '대게': 971,
#  '사실': 972,
#  '인정': 973,
#  '그닥': 974,
#  '틀리다': 975,
#  '드': 976,
#  '따르다': 977,
#  '채우다': 978,
#  '장소': 979,
#  '얼': 980,
#  '화가': 981,
#  '땡기다': 982,
#  '부분': 983,
#  '대구': 984,
#  '따뜻하다': 985,
#  '한두': 986,
#  '이야': 987,
#  '왓': 988,
#  '평소': 989,
#  '백숙': 990,
#  '가세': 991,
#  '딱이다': 992,
#  '별개': 993,
#  '감사': 994,
#  '사랑': 995,
#  '해산물': 996,
#  '런가': 997,
#  '다섯': 998,
#  '보단': 999,
#  '서서': 1000,
#  ...}

# %%
sequences = tokenizer.texts_to_sequences(okt_review)
print(sequences)

padded = pad_sequences(sequences)
print(padded)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [[    0     0     0 ...    41    86     3]
#  [    0     0     0 ...   621  1063  1674]
#  [    0     0     0 ...    89    12   175]
#  ...
#  [    0     0     0 ... 11010    10   537]
#  [    0     0     0 ...  4627   367  1551]
#  [    0     0     0 ...   447   142    20]]

# %% [markdown]
# 학습과 테스트 세트 분리

# %%
x_train = padded
y_train = df['NP']

# %%
from sklearn.model_selection import train_test_split

# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20)
print(x_train.shape)
# print(x_test.shape)
# Out:
# (50000, 481)

# %% [markdown]
# LSTM

# %%
from tensorflow.keras.layers import Embedding,Dense,LSTM
from tensorflow.keras.models import Sequential 
from tensorflow.keras.models import load_model 
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint

# %%
model = Sequential() 
model.add(Embedding(vocab_size,64)) 
model.add(LSTM(32)) 
model.add(Dense(1,activation='sigmoid'))

# %%
es = EarlyStopping(monitor='val_loss', mode = 'min', verbose = 1, patience=4) 
mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='max', verbose=1, save_best_only=True)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 64)          1082816
#
#  lstm (LSTM)                 (None, 32)                12416
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 1,095,265
# Trainable params: 1,095,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc']) 
history = model.fit(x_train, y_train, epochs=100, callbacks=[es,mc], batch_size=200, validation_split=0.2)
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3575 - acc: 0.8620
# Epoch 1: val_loss improved from -inf to 0.27629, saving model to best_model.h5
# 200/200 [==============================] - 97s 469ms/step - loss: 0.3575 - acc: 0.8620 - val_loss: 0.2763 - val_acc: 0.8971
# Epoch 2/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2404 - acc: 0.9141
# Epoch 2: val_loss did not improve from 0.27629
# 200/200 [==============================] - 99s 498ms/step - loss: 0.2404 - acc: 0.9141 - val_loss: 0.2666 - val_acc: 0.9013
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2195 - acc: 0.9234
# Epoch 3: val_loss did not improve from 0.27629
# 200/200 [==============================] - 90s 449ms/step - loss: 0.2195 - acc: 0.9234 - val_loss: 0.2645 - val_acc: 0.9016
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2064 - acc: 0.9277
# Epoch 4: val_loss did not improve from 0.27629
# 200/200 [==============================] - 86s 430ms/step - loss: 0.2064 - acc: 0.9277 - val_loss: 0.2678 - val_acc: 0.9000
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1957 - acc: 0.9304
# Epoch 5: val_loss did not improve from 0.27629
# 200/200 [==============================] - 90s 450ms/step - loss: 0.1957 - acc: 0.9304 - val_loss: 0.2759 - val_acc: 0.9005
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1856 - acc: 0.9347
# Epoch 6: val_loss improved from 0.27629 to 0.28133, saving model to best_model.h5
# 200/200 [==============================] - 88s 442ms/step - loss: 0.1856 - acc: 0.9347 - val_loss: 0.2813 - val_acc: 0.8983
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1760 - acc: 0.9380
# Epoch 7: val_loss improved from 0.28133 to 0.28175, saving model to best_model.h5
# 200/200 [==============================] - 93s 466ms/step - loss: 0.1760 - acc: 0.9380 - val_loss: 0.2817 - val_acc: 0.8946
# Epoch 7: early stopping

# %%
import numpy as np
import matplotlib.pyplot as plt

def show_history(history):
  plt.figure(figsize=(6, 6))
  plt.yticks(np.arange(0, 1, 0.05))
  plt.plot(history.history['acc'], label='train')
  plt.legend()

show_history(history)
