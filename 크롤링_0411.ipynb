# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import re
from collections import Counter
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("./seoul_food.csv", encoding='cp949')
df = df.drop(columns='Unnamed: 0')

# %%
df.head()
# Out:
#       구    동            사업장명  업종        좌표정보(X)        좌표정보(Y)
# 0   종로구  관철동              상해  분식  198867.702591  451824.281126
# 1   관악구  신림동              미쿠  일식  193687.348199  442284.164025
# 2   구로구  구로동      여름엔빙수겨울엔떡국  한식  189814.305919  443046.239859
# 3   강남구  대치동            카페디퍼  카페  204776.548264  444677.642985
# 4  동대문구  신설동  메이크데이(MakeDay)  카페  202114.228397  452392.093759

# %%
print('자치구 목록:', end= ' ')
for i in list(df['구'].unique()):
    print(i, end=' ')
print()
print('원하시는 자치구를 입력해주세요:')
gu = input()

print('자치동 목록:', end=' ')
for i in list(df[df['구'] == gu]['동'].unique()):
    print(i, end=' ')
print()
print('원하시는 자치동을 입력해주세요:')
dong = input()

print('음식종류 목록:', end=' ')
for i in list(df['업종'].unique()):
    print(i, end=' ')
print()
print('원하시는 음식종류를 입력해주세요:')
food = input()

food_list = df[df['구'] == gu][df['동'] == dong][df['업종'] == food]['사업장명'].tolist()
food_list
# Out:
# 자치구 목록: 종로구 관악구 구로구 강남구 동대문구 은평구 강북구 영등포구 중랑구 서초구 강서구 강동구 성동구 노원구 중구 성북구 도봉구 용산구 광진구 송파구 마포구 금천구 동작구 양천구 서대문구
# 원하시는 자치구를 입력해주세요:
# 강남구
# 자치동 목록: 대치동 논현동 역삼동 도곡동 신사동 청담동 자곡동 삼성동 압구정동 개포동 세곡동 일원동 수서동 일부)호
# 원하시는 자치동을 입력해주세요:
# 논현동
# 음식종류 목록: 분식 일식 한식 카페 양식 치킨 외국음식 중식 고기 해산물 술집 패스트푸드
# 원하시는 음식종류를 입력해주세요:
# 한식
# ['숯칼 도산 숯닭갈비',
#  '곱분이',
#  '백순대본가새맛',
#  '오르락내리락',
#  '고푸드코리아',
#  '공주빙수',
#  '광주식당',
#  '켈리 더 쿡(Kelly the cook)',
#  '영동 미락',
#  '호선생찜닭 8422 학동본점',
#  '(주)에스에프이노베이션 스쿨푸드논현딜리버리점',
#  '경성밥상 논현점',
#  '컨트롤브이',
#  '구일삼겹',
#  'SJ푸드',
#  '고향집',
#  '셀프키친 논현2호점',
#  '부산에서한남까지낙곱새',
#  '황제애상',
#  '주식회사 락',
#  '테즈쿠리 논현점',
#  '대박낙지',
#  '학동부대',
#  '(주)아리양',
#  '3단계 레드갈비찜',
#  '조선아구찜',
#  '구구족 강남논현점',
#  '신사정육식당',
#  '한사발포차',
#  '강남곱창이야기 본점',
#  '빈호(vinho)',
#  '송탄 그집 부대찌개 강남직영점',
#  '만만스토리',
#  '볶은커피',
#  '소제이 서울본점',
#  '후문',
#  '늘통큰감자탕',
#  '유즈스토어',
#  '알잘딱깔센',
#  '메이크 어 딜리버리',
#  '취중다마',
#  '죽이야기(강남지인점)',
#  '스팀피쳐',
#  '담미온 학동점',
#  '낙지꽃돈',
#  '명륜진사갈비 강남구청점',
#  '서희도시락',
#  '세광양대창 논현점',
#  '에이뿔램 논현점',
#  '영암집 2호점',
#  '언양불고기',
#  '괴기스러운 식당',
#  '골목길',
#  '이태리부대찌개(강남구청점)',
#  '청량리 광주냉면',
#  '진미 평양냉면',
#  '도도짝갈비',
#  '박콧털',
#  '김돈이',
#  '예삐네집',
#  '세자매복집',
#  '진진도시락',
#  '영동식당',
#  '(주)감나무집',
#  '평양면옥',
#  '쌀똑핫도그 논현점',
#  '청담이상 영동시장점',
#  '고향집',
#  '우정 양곱창',
#  '콩뿌리콩나물국밥 강남구청점',
#  '백곱식당 (강남구청역점)',
#  '우리단골집',
#  '우생',
#  '수묵당',
#  '강남주먹고기투',
#  '석이테이블',
#  '오브젝티브 커피 로스터스',
#  '아바이왕순대',
#  '지글이 돈',
#  '수정방',
#  '팔당닭발',
#  '대청마루',
#  '서초동연가',
#  '송학',
#  '청가',
#  '고향식당',
#  '페리테일(Ferry tail)',
#  '우도',
#  '영동소금구이 논현본점',
#  '강남고기집 신칠성집',
#  '반 피차이',
#  '제주서부두식당',
#  '만덕식당 신사점',
#  '깐쵸 간장 새우',
#  '민속칼국수',
#  '완도 1957',
#  '동해별관',
#  '아나고야 1호점',
#  '꼼터',
#  '요기당',
#  '대삼식당',
#  '주식회사 안동한우원',
#  '장미술상',
#  '통영다찌',
#  '더진국 수육국밥(논현점)',
#  '노란상 소갈비 강남구청점',
#  '왕코 등갈비',
#  '금보성',
#  '동해종합어시장',
#  '부산집',
#  '대가',
#  '부엉이 식당',
#  '청국장전문점',
#  '저스트',
#  '더램',
#  '까미',
#  '휴',
#  '국민집밥 정식당',
#  '크래버대게나라',
#  '손맛 순대국',
#  '와도돼지',
#  '청계산갈비살',
#  '화포식당 논현점',
#  '곱창이야기 청담에스에이치그룹',
#  '겨울. 그리고 봄 2호점',
#  '홍명',
#  '땅코참숯구이',
#  '광부한우',
#  '토담김치찌개',
#  '폭풍갈비',
#  '들꽃향기시골밥상',
#  '탑회수산',
#  '그레잇이삼칠',
#  '더 와인(The wine)',
#  '이끼',
#  '목포자매집',
#  '한남동24시뼈다귀감자탕 분점',
#  '양식당 더램키친',
#  '마포네',
#  '마장동박현규(주) 1호점',
#  '해물꽃돈',
#  '사람사는고깃집 김일도 신논현점',
#  '어미향',
#  '부대찌개매니아 돈돌',
#  '(주)아가페하우스',
#  '한솥도시락 논현초등학교옆점',
#  '진미 평양냉면',
#  '장성생태전문점',
#  '버크셔 & 듀록',
#  '호세야 오리 바베큐',
#  '논현 조개전골',
#  '프로간장새우 1호점',
#  '양돈',
#  '빽돈 신논현직영점2',
#  '엄마냉장고',
#  '똥싸게',
#  '세종한우',
#  '행복밥상',
#  '임명 진오돌뼈본점',
#  '위너',
#  '삼호짱뚱이',
#  '얼큰이네',
#  '한우당',
#  '만구기네',
#  '강구항',
#  '명동칼국수',
#  '파이굽는집',
#  '마봉양꼬치',
#  '제주도흑돼지',
#  '힐탑식당',
#  '명동칼국수 샤브샤브',
#  '영심이네야식',
#  '주전자',
#  '해랑가정식백반',
#  '풍천장어',
#  '응급실밥상술상&쭈상낙원',
#  '고흥집',
#  '양평해장국',
#  '아나고야',
#  '개성집',
#  '헤라하우스',
#  '신비주주',
#  '섬마을이야기',
#  '리북집',
#  '삼계향',
#  '손칼국수',
#  '오락',
#  '세꼬시닷컴',
#  '신의주 부대찌게',
#  '삼육가',
#  '송가네',
#  '토가라시',
#  '부잣집',
#  '중진담',
#  '서울황태',
#  '어서옵쇼',
#  '휴네츠아시아북해도',
#  '한신포차',
#  '닭발상점',
#  '종로 닭한마리',
#  '거복',
#  '어사출또',
#  '논골집 영동점',
#  '현대순대국',
#  '마포숯불갈비',
#  '내아들밥상',
#  '문경세재',
#  '송씨해물별관',
#  '늘푸른',
#  '입속행복 리북집',
#  '봉골레숲',
#  '가시리',
#  '자연담',
#  '유쾌한접시',
#  '영동민속전집',
#  '강남골',
#  '은주네분식',
#  '골목길2',
#  '아구본가 첨벙 신사본점',
#  '투다리',
#  '팔꾸이',
#  '쏭쏭문어',
#  '(주)달맞이',
#  '교촌치킨 논현1호점',
#  '내당한우',
#  '새우의 진수',
#  '청석골식당',
#  '더 바른 정육식당',
#  '신사면옥',
#  '스트리트',
#  '원석이네',
#  '봉남 부추꼬꼬',
#  '제주탐하리',
#  '체',
#  '광주섬진강',
#  '옛날농장',
#  '속초명가',
#  '오수양푼이동태탕',
#  '육덕등심',
#  '창우수산 활새우직판장',
#  '역전할머니 맥주 신논현점',
#  '영동원삼겹살',
#  '사랑채',
#  '난장캠프',
#  '수라밥상',
#  '논현손국수',
#  '다옴',
#  '아리아',
#  '송림',
#  '만구기네(영동시장점)',
#  '이모네',
#  '논현참족발',
#  '딸바요',
#  '아침가리긴밭',
#  '곤지암 할매 소머리 국밥',
#  '대가연',
#  'Beer2DDa(비어이따 강남점)',
#  '낭풍',
#  '어사어 막회',
#  '일품황소곱창',
#  '명진푸드',
#  '동남아 식당',
#  '김가네',
#  '왕선왕족발보쌈',
#  '왕고모',
#  '순천만식당',
#  '청평숯불갈비',
#  '늘해랑',
#  '(주)온세일육팔요',
#  '쭈꾸미 한상',
#  '조선화로집(학동역점)',
#  '신사뻘낙지',
#  '홍도야지',
#  '방일해장국',
#  '달맞이',
#  '명동칼국수',
#  '곱창마을',
#  '정원',
#  '왕빈자삼파전',
#  '요시야',
#  '제이에스(JS)가든 블랙',
#  '대삼식당',
#  '포인트',
#  '천상애 장어가',
#  '만득이곱창',
#  '김이순장춘',
#  '신의주 찹쌀순대 학동점',
#  '멜로디',
#  '동천홍 학동점',
#  '독집',
#  '심가네칼국수',
#  '막내네',
#  '단지',
#  '제니스라운지',
#  '두레식당',
#  '911 돼지',
#  '(주)삼원가든 투뿔등심 논현본점',
#  '노포식당 논현본점',
#  '이장군카레와',
#  '하남돼지집(학동역)',
#  '푸니양강',
#  '원할머니 국수 보쌈 논현점',
#  '주주식당',
#  '아지트',
#  '달인포차',
#  '엘리에나호텔',
#  '국민고기냉면연구소(논현점)',
#  '쏠트마인(ssaltmine)',
#  '샤모니',
#  '한교방 서울면옥',
#  '막둥네국시',
#  '풍원',
#  '박성희가 요리하는 집',
#  '문',
#  '봉평본가메밀촌',
#  'BANN JOO 79 (반주)',
#  '미우가',
#  '디히랑',
#  '그때그집',
#  '사랑방',
#  '빽돈(신논현 직영점)',
#  '팔덕식당',
#  '해솔',
#  '오정삼미',
#  '위클리푸드',
#  '베니스',
#  '와이식당',
#  '퍼블릭 에이치(H)',
#  '강남웨딩 출장부페',
#  '다다돈까스',
#  '감동돼지 학동역점',
#  '은화계',
#  '정성담은 사골한돈 김치찌개',
#  '갓잡은 숙성한돈 돼지고기집',
#  '영동실비',
#  '이모네로',
#  '게순이네식당',
#  '양출쿠킹',
#  '남다른감자탕 강남을지병원사거리점',
#  '종로계림닭도리탕원조 논현점',
#  '유에프오키친',
#  '포트캔커피 논현점',
#  '신의주찹쌀순대 논현역점',
#  '배달삼겹 맛있으면돼지',
#  '양평 진뚝배기해장국',
#  '(주)삼원가든 뿔사롱 논현점',
#  '영동곱창',
#  '달봉이치킨(논현점)',
#  '강남쪽갈비',
#  '우담',
#  '(주)입속행복 리북집',
#  '남포면옥',
#  '찌개마을시골촌',
#  '논현감자탕',
#  '양양불떡볶이',
#  '게방식당',
#  '네모오징어 강남논현점',
#  '광주육전',
#  '교동한식',
#  '천사곱창 논현점',
#  '완성식당',
#  '마켓정',
#  '김볶키친',
#  '직화뚝배기',
#  '논현담설렁탕',
#  '원갈비',
#  '봉산평양냉면',
#  '또래오래 논현&대가집',
#  '남다른감자탕 학동사거리점',
#  '통돼지네',
#  '논현밀밭',
#  '사람사는고깃집김일도(논현점)',
#  '논현닭한마리',
#  '바라양푼이MJ부대찌개',
#  '맛있는하루',
#  '냠냠익스프레스',
#  '고기듬뿍 대왕비빔밥 논현점',
#  '우기식당',
#  '시즈오카 돈카츠',
#  '우기식당 육지점',
#  '매일쏜다 딜리버리',
#  '와인주막차차 강남구청역점',
#  '엄마밥상',
#  '사랑채',
#  '우미각',
#  '신의주 찹쌀순대',
#  '강화통통생고기 논현점',
#  '강남불백',
#  '한사바리 해장국',
#  '쭈블링쭈꾸미볶음',
#  '문어야',
#  '하자 엔터테인먼트',
#  '해물꽃소',
#  '세종한우 샤브샤브 전문점',
#  '봉추찜닭 강남구청역점',
#  '진전복 삼계탕 본점',
#  '옥돌식당',
#  '팔당 충무김밥 국수',
#  '와우-싱싱횟집',
#  '빛고을',
#  '에비바',
#  '청송숯불화로구이',
#  '세이아',
#  '엠(M)',
#  '남서울민물장어',
#  '김선생 조개찜',
#  '별미식당',
#  '88선수촌',
#  '유쾌한접시',
#  '영암집 1호점',
#  '소나무',
#  '혼술대왕(강남점)',
#  '엔에스 푸드',
#  '촌돼지마을2',
#  '황소곱창',
#  '방배김밥이 만든 라이스쉐프 강남구청역점',
#  '징기스칸',
#  '혼밥증권',
#  '팔각도 논현점',
#  '씬(ssiin)',
#  '춘이네반반집 논현본점',
#  '연스시',
#  '엔틱정 강남논현점',
#  '본죽앤비빔밥카페 논현점',
#  '김가네김밥',
#  '수수한상',
#  '진대감',
#  '제주섬애',
#  '신 꼬추장',
#  '산곰장어',
#  '하남돼지집 강남구청점',
#  '설수사',
#  '만포식당',
#  '퍼남사이곤',
#  '주방류',
#  '지니',
#  '은실이포차',
#  '청담 주먹고기',
#  '주식회사 원강',
#  '배꼽집',
#  '보전식당',
#  '순두부와삼겹살',
#  '밀라노푸드',
#  '전라도맛집',
#  '돼지연구소(2호점)',
#  '참새식당',
#  '복성맛집',
#  '청양칼국수',
#  '이자카야나무(논현점)',
#  '내수족발보쌈집',
#  '투원맥주 논현점',
#  '에그셀런트 논현점',
#  '완스키친',
#  '장어의전설',
#  '토담골',
#  '광개토정육식당',
#  '막걸리 전',
#  '모로미쿠시',
#  '영동빈대떡',
#  '논현장어',
#  '독도쭈꾸미',
#  '주식회사 원강 2호점',
#  '펀 비어킹(fun beerking)',
#  '음 세이로무시',
#  '지리산흙돼지',
#  '겨울바다',
#  '왓탕카',
#  '박실장 논현점',
#  '소풍',
#  '미미',
#  '이백서서갈비',
#  '큰물참치',
#  '이대팔 쭈꾸미',
#  '주)성보마리아쥬',
#  '바다로가자',
#  '돼지코코',
#  '모모',
#  '간단포차',
#  '소공동 뚝배기',
#  '입e 편한집',
#  '돈까스의집',
#  '토말',
#  '계열사 논현점',
#  '세림정',
#  '논골집',
#  '다왕래 장어구이(논현점)',
#  '굿사마리안레시피',
#  '무쇠막 김치찌게',
#  '텐트리키친',
#  '쿠시라쿠',
#  '동막촌',
#  '최전방부대찌개',
#  '신사김밥',
#  '마요네즈 신논현점',
#  '토영자갈치곰장어',
#  '전나라쭈꾸미',
#  '김명자굴국밥',
#  '마산아구찜',
#  '육갑식당',
#  '노바인 헤븐(No Bar In Heaven)',
#  '한정식애덕',
#  '이층 고깃집',
#  '강남설렁탕',
#  '한마리소',
#  '(주)오리온마켓오압구정점',
#  '진도리 닭도리탕',
#  '키즈앤맘',
#  '떼부짱',
#  '(주)도라후구현복집',
#  '고메스테이크 논현점',
#  '모토',
#  '강남집밥2',
#  '두모감자탕',
#  '김태준의 탕탕집',
#  '유장원보쌈',
#  '지리산',
#  '정운',
#  '허당맛선생',
#  '진배족발',
#  '너또오리',
#  '촌돼지마을',
#  '자연스케치',
#  '바다축제',
#  '논현보물섬',
#  '가리비야',
#  '돈수백논현점',
#  '우리곱창',
#  '태백식당',
#  '네모집',
#  '담담',
#  '두릉도원 북촌순두부',
#  '원조상석안동갈비',
#  '영동민물장어',
#  '김봉남 포장마차',
#  '진도집',
#  '해몽마포갈비',
#  '모우정',
#  '옛날칼국수',
#  '경동관 나주곰탕나주전',
#  '논현역2번출구',
#  '청호',
#  '육화몽 논현점',
#  '돌우물',
#  '강꼬스시',
#  '핫이슈(HOT EATSUE)',
#  '청담이상',
#  '옐로우키친',
#  '고씨네 고추장찌개(신논현점)',
#  '엔237다이닝펍(N237 Dining Pub)',
#  '배달육회 육회한가득 신사논현점',
#  '최강달인춘천닭갈비.막국수',
#  '청기와',
#  '(주)핫시즈너 동대문엽기떡볶이',
#  '송화전',
#  '학동이베리코',
#  '논현갈비',
#  '탑 포차',
#  '쿠시 쿠시',
#  '함지곱창',
#  '헬로우치킨',
#  '나비식탁',
#  '두어마리',
#  '유정식당',
#  '나향반점',
#  '장수설렁탕',
#  '도리토리본점',
#  '술이 그린 밤',
#  '가람국시',
#  '천산',
#  '현대순대국',
#  '이가네',
#  '영번지',
#  '서울왕돈까스',
#  '꽃뱅이',
#  '함박곱창족발',
#  '이모가있는집',
#  '동천홍 논현점',
#  '엄마백반',
#  '논현생고기',
#  '최가맛뜸',
#  '맹그르브 삼겹살',
#  '자연석돌구이',
#  '한우리외식산업(주)',
#  '용삼계탕',
#  '60년 전통 신촌 황소곱창',
#  '삼미',
#  '한울 닭갈비',
#  '짱이네',
#  '삼청동 뚝배기',
#  '서울촌놈수육국밥 신사점',
#  '강남아씨죽',
#  '복게장',
#  '정보인부산돼지국밥',
#  '유성칼국수',
#  '현정키친',
#  '김천재의 육회반한연어',
#  '부산 아지매 국밥 신논현역점',
#  '갯벌의진주',
#  '한성칼국수',
#  '공룡닭발 논현점',
#  '88식당 신논현점',
#  '벤투스캐롬카페',
#  '백암순대국.뼈해장국',
#  '영동그집',
#  '(주)세컨드유레카 선릉DV점',
#  '완도1957학동사거리점',
#  '탄',
#  '두찜 강남논현점',
#  '우기식당 육지2호점',
#  '달달하이',
#  '미월당 논현점',
#  '키친몬',
#  '신논현맛집 장남식당',
#  '보승회관 강남구청역점',
#  '화랑불닭발',
#  '화랑불닭',
#  '놀부주방 보쌈오불장군김치찜 논현점',
#  '논현집',
#  '맨션',
#  '육개옥',
#  '완도1957별관',
#  '언니네 집밥 1호점',
#  '백암왕순대',
#  '다온 바이 뱀부(DAON by Bamboo)',
#  '포장마차촌 논현점',
#  '무교동낙지',
#  '보승회관(을지병원사거리)',
#  '논현삼겹',
#  '미가한우. 치킨처럼',
#  '씨앤에프',
#  '카이스파',
#  '원조소금구이',
#  '유로포차',
#  '카츠반',
#  '언니네',
#  '배달삼겹 맛있으면 돼지',
#  '착한 덮밥',
#  '상황버섯 약수삼계탕',
#  '본죽앤비빔밥강남구청역점',
#  '헬로포크',
#  '밥달나무',
#  '죽도령',
#  '육칠팔 딜리버리',
#  '죤슨앤바오',
#  '도시와자연',
#  '가나돈가스',
#  '기대만족 강남본점',
#  '푸드코트101',
#  '순딜리버리 6호점',
#  '순딜리버리 13호점',
#  '순딜리버리 1호점',
#  '순딜리버리 9호점',
#  '순딜리버리 4호점',
#  '순딜리버리 5호점',
#  '롤리폴리 꼬또(Roly Poly Cotto)',
#  '인생김치찌개(논현점)',
#  '카바동',
#  '화다인',
#  '게브라더스',
#  '사라네순대국',
#  '영남식육식당',
#  '북촌순대',
#  '미랑이랑',
#  '참달달한포차',
#  '카페(cafe)781',
#  '킹콩부대찌개 논현아이파크점',
#  '곰다방',
#  '맛앤멋',
#  '정육점아저씨의 투잡',
#  '제국한우짝갈비',
#  '품앗이',
#  '간판없는 김치찌개 강남직영점',
#  '송파만두 강남점',
#  '덮밥파는 덮밥집 학동점',
#  '대도숯불갈비덮밥',
#  '초월관',
#  '바 페르갈 bar fergal',
#  '달잔',
#  '코코여성사우나',
#  '착한부자F&B',
#  '3일한우국밥 논현직영점',
#  '형수곱창',
#  '강아지똥',
#  '논현빈대떡',
#  '비노쿠스 테이블',
#  '해목',
#  '빙수 부티크 본점',
#  '연탄구이',
#  '고소미부엌 본점',
#  '심푸드',
#  '삼청골명가 The 수제비',
#  '신차우',
#  '꽃삼살롱',
#  '무교동유정낙지본점 논현배달점',
#  '알촌 논현직영점',
#  '돈기부여 강남점',
#  '대게만찬',
#  '한식 1번가',
#  '영희네포차',
#  '도산뚝배기',
#  '빙츄르',
#  '한상갈비찜',
#  '푸드코트',
#  '푸라벨(Food-life balance)',
#  '한양김밥 논현곱창',
#  '천호용궁알탕 강남서초점',
#  '눈치까스',
#  '한식밥상',
#  '원&승',
#  '시키고 논현점',
#  '물고기자리',
#  '게슐랭',
#  '팔공키친',
#  '(주)핫토리 동대문엽기떡볶이 강남구청역점',
#  '먹어도 돼지',
#  '보하라 학동점',
#  '삼시세끼 셰프반찬',
#  '바른보쌈 1990 논현점',
#  '강씨가문의 족발',
#  '갤럭시',
#  '노들강',
#  '육회와 연어',
#  '갤러리',
#  '비(B)',
#  '부부불이 동대문닭한마리',
#  '백제한방삼계탕',
#  '비빔명가 쿨한냉면',
#  '조선 국밥',
#  '남원우가',
#  '몬스터 컴퍼니',
#  '그레잇팩토리 강남본점',
#  '난바우동 강남본점',
#  '본가설렁탕',
#  '슈엔 산업',
#  '엘티에프앤비(LT F&B)',
#  '음악형제들(mubro)',
#  '청춘 F&B',
#  '통삼집',
#  '숯불',
#  '베비스토어 논현',
#  '루나',
#  '공존(편안하개)',
#  '하남돼지집 신논현역점',
#  '강명수 아저씨네',
#  '선녀와 나무꾼',
#  '이모네왕곱창',
#  '학동역점 본죽&비빔밥',
#  '명소한우',
#  '아프릴로',
#  '시저스 홀덤',
#  '본가삼겹살&차돌된장 논현점',
#  '샐러드몬스터',
#  '인생족발 논현점',
#  '한입에꿀닭',
#  '케렌시아.장금이네',
#  '(주)삼다연',
#  '맛소담',
#  '부찌식당',
#  '7번가피자 논현점',
#  '소곱당',
#  '팬타스틱 아시아',
#  'D.5414',
#  '인생아구찜',
#  '가족회관 강남구청점',
#  '보다',
#  '판도 푸드',
#  '동경야시장 논현점',
#  '볶튀혈전',
#  '완미족발 논현본점',
#  '배달육회 육회한가득',
#  "드렁큰칠리스(Drunken chili's)",
#  '언더락위스키',
#  '조선제일족발',
#  '두성전주콩나물국밥 강남구청역점',
#  '한서외식산업(주)',
#  '좋은친구',
#  '현해',
#  '해물꽃돈 직영점',
#  '(주)낙타브루잉',
#  '생선물은 고양이',
#  '피노키오 피자 PINOCCHIO PIZZA',
#  '테이스티나인 델리익스프레스(Tasty9 Deli Express) 학동점',
#  '구월의 소철',
#  '주식회사 취중진담 우연',
#  '강남구',
#  '(주)화춘옥청담',
#  '제주생선구이 올래밥상',
#  '매일공기 논현1호점',
#  '머드내 갈비살',
#  '악마떡볶이&닭발',
#  '지안정',
#  '본가마순대국',
#  '청담보쌈',
#  '냄비닭발 선릉점',
#  '주니냉면',
#  '정동길논현',
#  '완도1957 전복삼계탕 논현점',
#  '우쿠야 논현 키친밸리점',
#  '끼니위드팜(강남논현점)',
#  '주식회사 우아한카페앤프레쉬논현',
#  '샐러우드',
#  '우아한논현카페앤프레쉬',
#  'WCF F&B 논현',
#  '학동커피',
#  '라피네',
#  '샐러딜라이트',
#  '저스트샐러드',
#  '요거프룻',
#  '연이네 토스트',
#  '탐나종합어시장 논현동점',
#  '또온나 불닭',
#  '삼겹품은 김치찌개 논현점',
#  '육회파는연어집',
#  '어반박스(Urbanbox) 도시락',
#  '장모님찌개 논현점',
#  '추풍령 소한마리탕 직영 2호점',
#  '본리스치킨',
#  '장하다 학동점',
#  '후쿠오카 호르몬동 강남점',
#  '간판없는 부대찌개',
#  '톤토로 식당 항정살 전문 논현점',
#  '나고야 히초마부시 장어덮밥',
#  '우아한논현키친',
#  '한미옥',
#  '논현각',
#  '냉삼식당',
#  '백미우',
#  '해랑',
#  '에그폭탄덮밥(논현점)',
#  '죠스익스프레스 논현본점',
#  '와플본가',
#  '샌드박스',
#  '행보케포케',
#  '카페얌',
#  '사다리카페',
#  '공주네디저트',
#  '혼밥대왕',
#  '푸드씨',
#  '명당 술이 맛있는 집',
#  '논현중화식당',
#  '원식당',
#  '현경이네',
#  '프레퍼스 다이어트 푸드 강남구청점',
#  '여행푸드',
#  '인터렉트',
#  '류몽민',
#  '류창희국수人',
#  '장또방김치찌개']
